# %%
# config.py

# Database settings
DB_TYPE = "sqlite"  # or "json"
DB_PATH = "data/payroll.db"  # path to your SQLite database or JSON file

# Admin credentials
ADMIN_ID = "HR0001"
ADMIN_PASSWORD_HASH = "your_hashed_password_here"  # hash passwords using MD5, bcrypt, etc.

# Payroll settings
DEFAULT_HOURLY_PAY = 20.0
STANDARD_WORK_HOURS = 40

# Tax rates
STATE_TAX = 0.0315
FEDERAL_TAX = 0.0765
SOCIAL_SECURITY = 0.062
MEDICARE = 0.0145

# Medical and dependent allowances
MEDICAL_SINGLE = 50
MEDICAL_FAMILY = 100
DEPENDENT_STIPEND = 45
