# %%
import tkinter as tk
from tkinter import messagebox

def calculate_payroll():
    try:
        hours = float(hours_entry.get())
        
        gross_pay = hours * rate
        result_label.config(text=f"Gross Pay: ${gross_pay:.2f}")


    except ValueError:
        messagebox.showerror("Input Error", "Please enter valid numbers.")


def main():
    global hours_entry, rate_entry, result_label

    root = tk.Tk()
    root.title('Payroll Calculator")
    root.geometry("300x250")

    tk.Label(root, text="Hours Worked").pack(pady=5)
    hours_entry.packi()

    tk.Label(root, text="Hourly Rate").pack(pady=5)
    rate_entry = tk.Entry(root)
    rate_entry.pack()

    tk.Button(
        root,
        text="Calculate Payroll",
        command=calculate_payroll
    ).pack(pady=15)

    result_label = tk.Label(root, text="")
    result_label.pack()

    root.mainloop()


if__name__=="__main__":
    main()
